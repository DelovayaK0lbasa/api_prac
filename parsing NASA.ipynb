# %%
import requests
import json
from PIL import Image
from io import BytesIO

# %%
URL = 'https://api.nasa.gov/mars-photos/api/v1/rovers/curiosity/photos?earth_date=2022-4-8&api_key=DEMO_KEY'
req = requests.get(URL)
data = req.json()

# %%
photos = data['photos'][14:17]
photos = list(map(lambda x: x['img_src'], photos))
photos
# Out:
# ['https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03438/opgs/edr/ccam/CR0_702691469EDR_F0940574CCAM03437M_.JPG',
#  'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03438/opgs/edr/ccam/CR0_702690731EDR_F0940574CCAM03437M_.JPG',
#  'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03438/soas/rdr/ccam/CR0_702691469PRC_F0940574CCAM03437L1.PNG']

# %%
Image.open(BytesIO(requests.get(photos[0]).content))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1024x1024 at 0x210CDF117C0>

# %%
Image.open(BytesIO(requests.get(photos[1]).content))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1024x1024 at 0x210CE774D00>

# %%
Image.open(BytesIO(requests.get(photos[2]).content))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=1024x1024 at 0x210CE774610>
